# %% [markdown]
# <a href="https://colab.research.google.com/github/aayushbhurtel/Discrete_Math/blob/main/BhurtelAayush_CPSMA_3913_Project_5_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Discrete Mathematics
# ## Aayush Bhurtel
# ## Project 5 - Structures

# %% [markdown]
# I am here creating a tree of popular tv series namely "Game of Thrones" with specifically "Stark Family".

# %%
import graphviz

dot = graphviz.Digraph()
dot.node('A', 'Richard Stark')
dot.node('B', 'Brandon Stark')
dot.node('C', 'Edward Stark') # ed
dot.node('J', 'Katelyn Tully') # kat
dot.node('Z', 'Edward and Katelyn')
dot.node('D', 'Benjen Stark')
dot.node('E', 'Lyanna Stark')
dot.node('F', 'Rhaegar Targaryen')
dot.node('G', 'Robb Stark')
dot.node('H', 'Sansa Stark')
dot.node('I', 'Arya Stark')
dot.node('K', 'Bryan Stark')
dot.node('L', 'Rickon Stark')
dot.node('M', 'Jon Snow')

dot.edges(['AB', 'AC','AD','AE','CZ','JZ','ZG','ZH','ZI','ZK','ZL','EM','FM'])
dot

# %% [markdown]
# ![stark.png](data:image/png;base64,...)

# %% [markdown]
# (c) Describe a path in your structure.
#
# => Path in my structure goes by the family tree where Richard Stark is the dad for 4 children namely, Brandon, Edward, Benjen and Lyanna Stark. Edward Stark is married to Katelyn Tully so next nodes are their 5 childern Robb, Sansa, Arya, Bryan and Rickon. Richard's daughter is married to Rhaegar Targaryen and their child us Jon Snow.
#
# (d) Describe the degree of a vertex.
# => degree of vertex (Richard Stark) is 4 where as (Edward and Katelyn) is 5.
#
# (e) Describe a cycle in your structure if it exists. If a cycle does not exist, explain how you know
# => There is no cycle in my structure, once the character is born, they die at some point so there is no cycle.

# %% [markdown]
# (a) Describe your findings in words.
#
# => This struture will visually clearify the realationship between the characters of a show and clear any consfusion.
#
# (b) Tell the story your structure shows.
#
# => This structure shows the childern of a parent as a parent node and child nodes. People familier with this show will understand this tree very quickly. This visualization will help everyone to understand the characters of House Stark in Game of Thrones.
